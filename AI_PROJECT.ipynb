# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanosama/AI-PROJECT-2026/blob/main/AI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "/tmp/ipykernel_2943/2055691193.py", line 1
#     AI_Project:
#                ^
# SyntaxError: invalid syntax
